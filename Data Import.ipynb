# %%
#Guerrero Diego
import numpy as np
import pandas as pd
import requests
import json

# %%
#CSV 
train = pd.read_csv("https://data.cityofnewyork.us/api/views/25th-nujf/rows.csv?accessType=DOWNLOAD")

# %%
train
# Out:
#        Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0               2016  FEMALE  ASIAN AND PACIFIC ISLANDER             Olivia
# 1               2016  FEMALE  ASIAN AND PACIFIC ISLANDER              Chloe
# 2               2016  FEMALE  ASIAN AND PACIFIC ISLANDER             Sophia
# 3               2016  FEMALE  ASIAN AND PACIFIC ISLANDER               Emma
# 4               2016  FEMALE  ASIAN AND PACIFIC ISLANDER              Emily
# 5               2016  FEMALE  ASIAN AND PACIFIC ISLANDER                Mia
# 6               2016  FEMALE  ASIAN AND PACIFIC ISLANDER          Charlotte
# 7               2016  FEMALE  ASIAN AND PACIFIC ISLANDER              Sarah
# 8               2016  FEMALE  ASIAN AND PACIFIC ISLANDER           Isabella
# 9               2016  FEMALE  ASIAN AND PACIFIC ISLANDER             Hannah
# 10              2016  FEMALE  ASIAN AND PACIFIC ISLANDER              Grace
# ...

# %%
#TXT
text = pd.read_fwf("http://www.gutenberg.org/files/60268/60268-0.txt")

# %%
text
# Out:
#      The Project Gutenberg EBook of Covered With Mud and Glory, by Georges Lafond
# 0     This eBook is for the use of anyone anywhere i...
# 1     most other parts of the world at no cost and w...
# 2     whatsoever.  You may copy it, give it away or ...
# 3     of the Project Gutenberg License included with...
# 4     www.gutenberg.org.  If you are not located in ...
# 5     have to check the laws of the country where yo...
# 6                                           this ebook.
# 7                     Title: Covered With Mud and Glory
# 8     A Machine Gun Company in Action ("Ma Mitraille...
# 9                                Author: Georges Lafond
# 10                          Contributor: Maurice Barrès
# 11                                   Georges Clemenceau
# 12                          Translator: Edwin Gile Rich
# 13       Release Date: September 9, 2019 [EBook #60268]
# 14                                    Language: English
# ...

# %%
#JSON
jason = requests.get("https://data.cityofnewyork.us/api/views/25th-nujf/rows.json?accessType=DOWNLOAD")

# %%
file = json.loads(jason.content)

# %%
file
# Out:
# {'meta': {'view': {'id': '25th-nujf',
#    'name': 'Popular Baby Names',
#    'attribution': 'Department of Health and Mental Hygiene (DOHMH)',
#    'averageRating': 0,
#    'category': 'Health',
#    'createdAt': 1382724894,
#    'description': 'Popular Baby Names by Sex and Ethnic Group\r\nData were collected through civil birth registration. Each record represents the ranking of a baby name in the order of frequency. Data can be used to represent the popularity of a name. Caution should be used when assessing the rank of a baby name if the frequency count is close to 10; the ranking may vary year to year.',
#    'displayType': 'table',
#    'downloadCount': 60665,
#    'hideFromCatalog': False,
#    'hideFromDataJson': False,
#    'indexUpdatedAt': 1536848918,
#    'newBackend': True,
#    'numberOfComments': 0,
#    'oid': 29513473,
#    'provenance': 'official',
#    'publicationAppendEnabled': False,
#    'publicationDate': 1534520388,
#    'publicationGroup': 1286739,
# ...
